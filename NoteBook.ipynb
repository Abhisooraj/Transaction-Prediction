# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
warnings.warn('my warning')

# %%
train_file=pd.read_csv("train.csv")
# shape of the file
print(train_file.shape)
train_file.head(5)
# Out:
# (32820, 44)
#       id account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0  23334       saving      M   63          305      7695.00          NaN
# 1  20329      current      M   33          326     52702.00       988.72
# 2  17679      current      M   44          264     10800.49      3215.52
# 3  16428       saving      M   44          233     20936.00          NaN
# 4  18721       saving      F   35          324      1183.83          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun   ...     debit_count_may  \
# 0       479.00          NaN        622.0   ...                 2.0
# 1     29873.00          NaN       1087.0   ...                10.0
# 2     21659.64       1607.0       1168.0   ...                 7.0
# 3      2094.00          NaN      11778.5   ...                 1.0
# 4      3656.29          NaN        945.0   ...                 3.0
#
#    max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# ...

# %%
test_file1=pd.read_csv("test.csv")
# shape of the file
print(test_file1.shape)
test_file1.head(5)
# Out:
# (14067, 43)
#       id account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0   6975       saving      M   36          447     17942.70       1170.0
# 1  43223      current      M   31          233     44870.36          NaN
# 2  45502      current      M   26          823      1073.00       2442.0
# 3  12368      current      M   39          878     33060.58          NaN
# 4  40415      current      M   44          404     18236.90          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun     ...      credit_count_may  \
# 0      1656.00          NaN      4551.00     ...                   3.0
# 1     34177.00          NaN     25889.21     ...                   NaN
# 2      4141.00        390.0      6740.29     ...                   4.0
# 3      3797.12          NaN       291.00     ...                   4.0
# 4     30513.30          NaN     20395.28     ...                   1.0
#
#    debit_count_may  max_credit_amount_may  debit_amount_jun  \
# ...

# %%
#dropping id column cz it's not giving useful information
train_file=train_file.drop(['id'], axis=1)
print(train_file.shape)
train_file.head(5)
# Out:
# (32820, 43)
#   account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0       saving      M   63          305      7695.00          NaN
# 1      current      M   33          326     52702.00       988.72
# 2      current      M   44          264     10800.49      3215.52
# 3       saving      M   44          233     20936.00          NaN
# 4       saving      F   35          324      1183.83          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  dc_cons_jun   ...     \
# 0       479.00          NaN        622.0          NaN   ...
# 1     29873.00          NaN       1087.0      2806.24   ...
# 2     21659.64       1607.0       1168.0       355.00   ...
# 3      2094.00          NaN      11778.5          NaN   ...
# 4      3656.29          NaN        945.0          NaN   ...
#
#    debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0              2.0                45000.0          20215.85
# 1             10.0               150000.0         122037.66
# ...

# %%
test_file=test_file1.drop(['id'], axis=1)
test_file.head(5)
# Out:
#   account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0       saving      M   36          447     17942.70       1170.0
# 1      current      M   31          233     44870.36          NaN
# 2      current      M   26          823      1073.00       2442.0
# 3      current      M   39          878     33060.58          NaN
# 4      current      M   44          404     18236.90          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  dc_cons_jun     ...      \
# 0      1656.00          NaN      4551.00          NaN     ...
# 1     34177.00          NaN     25889.21          NaN     ...
# 2      4141.00        390.0      6740.29        642.0     ...
# 3      3797.12          NaN       291.00          NaN     ...
# 4     30513.30          NaN     20395.28          NaN     ...
#
#    credit_count_may  debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0               3.0              7.0                10000.0          17316.44
# ...

# %%
sns.countplot(x="account_type",data=train_file)

# %%
sns.countplot(x="account_type",data=test_file)

# %%
# Conversion of string values into numerical values
train_file.gender[train_file.gender == 'M'] = 1
train_file.gender[train_file.gender == 'F'] = 2
train_file.account_type[train_file.account_type == 'saving'] = 1
train_file.account_type[train_file.account_type == 'current'] = 2
train_file.loan_enq[train_file.loan_enq == 'Y'] = 1
train_file.head(5)
# Out:
#   account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0            1      1   63          305      7695.00          NaN
# 1            2      1   33          326     52702.00       988.72
# 2            2      1   44          264     10800.49      3215.52
# 3            1      1   44          233     20936.00          NaN
# 4            1      2   35          324      1183.83          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  dc_cons_jun   ...     \
# 0       479.00          NaN        622.0          NaN   ...
# 1     29873.00          NaN       1087.0      2806.24   ...
# 2     21659.64       1607.0       1168.0       355.00   ...
# 3      2094.00          NaN      11778.5          NaN   ...
# 4      3656.29          NaN        945.0          NaN   ...
#
#    debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0              2.0                45000.0          20215.85
# 1             10.0               150000.0         122037.66
# ...

# %%
# COnversion of categorical variable into numerical values
test_file.gender[test_file.gender == 'M'] = 1
test_file.gender[test_file.gender == 'F'] = 2
test_file.account_type[test_file.account_type == 'saving'] = 1
test_file.account_type[test_file.account_type == 'current'] = 2
test_file.loan_enq[test_file.loan_enq == 'Y'] = 1
test_file.head(5)
# Out:
#   account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0            1      1   36          447     17942.70       1170.0
# 1            2      1   31          233     44870.36          NaN
# 2            2      1   26          823      1073.00       2442.0
# 3            2      1   39          878     33060.58          NaN
# 4            2      1   44          404     18236.90          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  dc_cons_jun     ...      \
# 0      1656.00          NaN      4551.00          NaN     ...
# 1     34177.00          NaN     25889.21          NaN     ...
# 2      4141.00        390.0      6740.29        642.0     ...
# 3      3797.12          NaN       291.00          NaN     ...
# 4     30513.30          NaN     20395.28          NaN     ...
#
#    credit_count_may  debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0               3.0              7.0                10000.0          17316.44
# ...

# %%
train_file.isnull().sum()
# Out:
# account_type                 0
# gender                       0
# age                          0
# region_code                  0
# cc_cons_apr                  0
# dc_cons_apr              19052
# cc_cons_may                  0
# dc_cons_may              17339
# cc_cons_jun                  0
# dc_cons_jun              21297
# cc_count_apr              2399
# cc_count_may              1153
# cc_count_jun              1590
# dc_count_apr             19052
# dc_count_may             17339
# dc_count_jun             15497
# card_lim                     9
# personal_loan_active     30078
# vehicle_loan_active      31974
# personal_loan_closed     29937
# vehicle_loan_closed      31195
# investment_1             31394
# investment_2             30482
# investment_3             31488
# investment_4             32414
# debit_amount_apr          1890
# credit_amount_apr         3302
# debit_count_apr           1758
# credit_count_apr          1758
# max_credit_amount_apr     3302
# ...

# %%
# avg spend of credit card in train data 3 months it will give me same information about dataset
df_credit_avg_train= train_file[['cc_cons_apr', 'cc_cons_may', 'cc_cons_jun']].mean(axis=1)
df_credit_avg_train=pd.DataFrame(df_credit_avg_train,columns=['credit_cons_avg'])
df_credit_avg_train.head()
# Out:
#    credit_cons_avg
# 0      2932.000000
# 1     27887.333333
# 2     11209.376667
# 3     11602.833333
# 4      1928.373333

# %%
# avg spend of credit card in test data 3 months
df_credit_avg_test= test_file[['cc_cons_apr', 'cc_cons_may', 'cc_cons_jun']].mean(axis=1)
df_credit_avg_test=pd.DataFrame(df_credit_avg_test,columns=['credit_cons_avg'])
df_credit_avg_test.head()
# Out:
#    credit_cons_avg
# 0      8049.900000
# 1     34978.856667
# 2      3984.763333
# 3     12382.900000
# 4     23048.493333

# %%
# avg spend of debit card in train file 3 months
df_debit_avg_train = train_file[['dc_cons_apr', 'dc_cons_may', 'dc_cons_jun']].mean(axis=1)
df_debit_avg_train=pd.DataFrame(df_debit_avg_train,columns=['debit_cons_avg'])
df_debit_avg_train.head()
# Out:
#    debit_cons_avg
# 0             NaN
# 1         1897.48
# 2         1725.84
# 3             NaN
# 4             NaN

# %%
# avg spend of debit card in test file 3 months
df_debit_avg_test = test_file[['dc_cons_apr', 'dc_cons_may', 'dc_cons_jun']].mean(axis=1)
df_debit_avg_test=pd.DataFrame(df_debit_avg_test,columns=['debit_cons_avg'])
df_debit_avg_test.head()
# Out:
#    debit_cons_avg
# 0          1170.0
# 1             NaN
# 2          1158.0
# 3             NaN
# 4             NaN

# %%
# train_file=train_file.drop(['cc_cons_apr', 'cc_cons_may', 'cc_cons_jun','dc_cons_apr', 'dc_cons_may', 'dc_cons_jun'],axis=1)
train_file=pd.concat([train_file,df_debit_avg_train, df_credit_avg_train], axis=1)

# %%
test_file=pd.concat([test_file,df_debit_avg_test, df_credit_avg_test], axis=1)

# %%
print(train_file.shape)
train_file.head(5)
# Out:
# (32820, 45)
#   account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0            1      1   63          305      7695.00          NaN
# 1            2      1   33          326     52702.00       988.72
# 2            2      1   44          264     10800.49      3215.52
# 3            1      1   44          233     20936.00          NaN
# 4            1      2   35          324      1183.83          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  dc_cons_jun       ...         \
# 0       479.00          NaN        622.0          NaN       ...
# 1     29873.00          NaN       1087.0      2806.24       ...
# 2     21659.64       1607.0       1168.0       355.00       ...
# 3      2094.00          NaN      11778.5          NaN       ...
# 4      3656.29          NaN        945.0          NaN       ...
#
#    debit_amount_jun  credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0          20215.85            1279.37               7.0              3.0
# ...

# %%
print(test_file.shape)
test_file.head(5)
# Out:
# (14067, 44)
#   account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0            1      1   36          447     17942.70       1170.0
# 1            2      1   31          233     44870.36          NaN
# 2            2      1   26          823      1073.00       2442.0
# 3            2      1   39          878     33060.58          NaN
# 4            2      1   44          404     18236.90          NaN
#
#    cc_cons_may  dc_cons_may  cc_cons_jun  dc_cons_jun       ...         \
# 0      1656.00          NaN      4551.00          NaN       ...
# 1     34177.00          NaN     25889.21          NaN       ...
# 2      4141.00        390.0      6740.29        642.0       ...
# 3      3797.12          NaN       291.00          NaN       ...
# 4     30513.30          NaN     20395.28          NaN       ...
#
#    max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                10000.0          17316.44             5154.0
# ...

# %%
train_file=train_file.drop(['personal_loan_active','vehicle_loan_active','personal_loan_closed','vehicle_loan_closed'
                           ,'investment_1','investment_2','investment_3','investment_4','loan_enq','cc_cons_apr'
                            , 'cc_cons_may', 'cc_cons_jun','dc_cons_apr', 'dc_cons_may', 'dc_cons_jun'],axis=1 )
print(train_file.shape)
# Out:
# (32820, 30)

# %%
test_file=test_file.drop(['personal_loan_active','vehicle_loan_active','personal_loan_closed','vehicle_loan_closed'
                           ,'investment_1','investment_2','investment_3','investment_4','loan_enq','cc_cons_apr'
                            , 'cc_cons_may', 'cc_cons_jun','dc_cons_apr', 'dc_cons_may', 'dc_cons_jun'],axis=1 )
print(test_file.shape)
# Out:
# (14067, 29)

# %%
# handling missing values
train_file.cc_count_apr.fillna(0, inplace=True)
train_file.cc_count_may.fillna(0, inplace=True)
train_file.cc_count_jun.fillna(0, inplace=True)
train_file.dc_count_apr.fillna(0, inplace=True)
train_file.dc_count_may.fillna(0, inplace=True)
train_file.dc_count_jun.fillna(0, inplace=True)

# Calculate the median value for train_file['card_lim']
train_file['card_lim'].fillna((train_file['card_lim'].mean()), inplace=True)
train_file.debit_amount_apr.fillna(0, inplace=True)
train_file.credit_amount_apr.fillna(0, inplace=True)
train_file.debit_count_apr.fillna(0, inplace=True)
train_file.credit_count_apr.fillna(0, inplace=True)
train_file.max_credit_amount_apr.fillna(0, inplace=True)
train_file.debit_amount_may.fillna(0, inplace=True)
train_file.credit_amount_may.fillna(0, inplace=True)
train_file.credit_count_may.fillna(0, inplace=True)
train_file.debit_count_may.fillna(0, inplace=True)
train_file.max_credit_amount_may.fillna(0, inplace=True)
train_file.debit_amount_jun.fillna(0, inplace=True)
train_file.credit_amount_jun.fillna(0, inplace=True)
train_file.credit_count_jun.fillna(0, inplace=True)
train_file.debit_count_jun.fillna(0, inplace=True)
train_file.max_credit_amount_jun.fillna(0, inplace=True)
train_file.debit_cons_avg.fillna(0, inplace=True)
train_file.credit_cons_avg.fillna(0, inplace=True)

# %%
print(train_file.shape)
train_file.head(5)
# Out:
# (32820, 30)
#   account_type gender  age  region_code  cc_count_apr  cc_count_may  \
# 0            1      1   63          305           2.0           1.0
# 1            2      1   33          326          11.0          14.0
# 2            2      1   44          264           6.0           9.0
# 3            1      1   44          233           9.0           6.0
# 4            1      2   35          324           2.0           7.0
#
#    cc_count_jun  dc_count_apr  dc_count_may  dc_count_jun       ...         \
# 0           3.0           0.0           0.0           0.0       ...
# 1          11.0           1.0           0.0           6.0       ...
# 2           6.0           3.0           2.0          14.0       ...
# 3           6.0           0.0           0.0           0.0       ...
# 4           9.0           0.0           0.0           0.0       ...
#
#    max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# ...

# %%
test_file.isnull().sum()
# Out:
# account_type                0
# gender                      0
# age                         0
# region_code                 0
# cc_count_apr             1038
# cc_count_may              542
# cc_count_jun              634
# dc_count_apr             8230
# dc_count_may             7375
# dc_count_jun             6552
# card_lim                    3
# debit_amount_apr          847
# credit_amount_apr        1465
# debit_count_apr           788
# credit_count_apr          788
# max_credit_amount_apr    1465
# debit_amount_may         1001
# credit_amount_may        1495
# credit_count_may          897
# debit_count_may           897
# max_credit_amount_may    1495
# debit_amount_jun          945
# credit_amount_jun         663
# credit_count_jun          655
# debit_count_jun           655
# max_credit_amount_jun     663
# emi_active                  0
# debit_cons_avg           5633
# credit_cons_avg             0
# dtype: int64

# %%
# handling missing values
test_file.cc_count_apr.fillna(0, inplace=True)
test_file.cc_count_may.fillna(0, inplace=True)
test_file.cc_count_jun.fillna(0, inplace=True)
test_file.dc_count_apr.fillna(0, inplace=True)
test_file.dc_count_may.fillna(0, inplace=True)
test_file.dc_count_jun.fillna(0, inplace=True)

# Calculate the median value for train_file['card_lim']
test_file['card_lim'].fillna((test_file['card_lim'].mean()), inplace=True)
test_file.debit_amount_apr.fillna(0, inplace=True)
test_file.credit_amount_apr.fillna(0, inplace=True)
test_file.debit_count_apr.fillna(0, inplace=True)
test_file.credit_count_apr.fillna(0, inplace=True)
test_file.max_credit_amount_apr.fillna(0, inplace=True)
test_file.debit_amount_may.fillna(0, inplace=True)
test_file.credit_amount_may.fillna(0, inplace=True)
test_file.credit_count_may.fillna(0, inplace=True)
test_file.debit_count_may.fillna(0, inplace=True)
test_file.max_credit_amount_may.fillna(0, inplace=True)
test_file.debit_amount_jun.fillna(0, inplace=True)
test_file.credit_amount_jun.fillna(0, inplace=True)
test_file.credit_count_jun.fillna(0, inplace=True)
test_file.debit_count_jun.fillna(0, inplace=True)
test_file.max_credit_amount_jun.fillna(0, inplace=True)
test_file.debit_cons_avg.fillna(0, inplace=True)
test_file.credit_cons_avg.fillna(0, inplace=True)

# %%
print(test_file.shape)
test_file.head(5)
# Out:
# (14067, 29)
#   account_type gender  age  region_code  cc_count_apr  cc_count_may  \
# 0            1      1   36          447           6.0           2.0
# 1            2      1   31          233          13.0          19.0
# 2            2      1   26          823           3.0           5.0
# 3            2      1   39          878          16.0          12.0
# 4            2      1   44          404          42.0          38.0
#
#    cc_count_jun  dc_count_apr  dc_count_may  dc_count_jun       ...         \
# 0           6.0           1.0           0.0           0.0       ...
# 1          36.0           0.0           0.0           0.0       ...
# 2           2.0           8.0           3.0           3.0       ...
# 3          15.0           0.0           0.0           0.0       ...
# 4          20.0           0.0           0.0           0.0       ...
#
#    debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0              7.0                10000.0          17316.44
# ...

# %%
print("\n train file : \n")
print(train_file.isnull().sum())
print("\n test file : \n")
print(test_file.isnull().sum())
# Out:
#  train file :
#
# account_type             0
# gender                   0
# age                      0
# region_code              0
# cc_count_apr             0
# cc_count_may             0
# cc_count_jun             0
# dc_count_apr             0
# dc_count_may             0
# dc_count_jun             0
# card_lim                 0
# debit_amount_apr         0
# credit_amount_apr        0
# debit_count_apr          0
# credit_count_apr         0
# max_credit_amount_apr    0
# debit_amount_may         0
# credit_amount_may        0
# credit_count_may         0
# debit_count_may          0
# max_credit_amount_may    0
# debit_amount_jun         0
# credit_amount_jun        0
# credit_count_jun         0
# debit_count_jun          0
# max_credit_amount_jun    0
# emi_active               0
# cc_cons                  0
# debit_cons_avg           0
# credit_cons_avg          0
# dtype: int64
#
#  test file :
#
# account_type             0
# gender                   0
# ...

# %%
print("\n train file: \n")
print(train_file.info())
print("\n test file: \n")
print(test_file.info())
# Out:
#  train file:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32820 entries, 0 to 32819
# Data columns (total 30 columns):
# account_type             32820 non-null object
# gender                   32820 non-null object
# age                      32820 non-null int64
# region_code              32820 non-null int64
# cc_count_apr             32820 non-null float64
# cc_count_may             32820 non-null float64
# cc_count_jun             32820 non-null float64
# dc_count_apr             32820 non-null float64
# dc_count_may             32820 non-null float64
# dc_count_jun             32820 non-null float64
# card_lim                 32820 non-null float64
# debit_amount_apr         32820 non-null float64
# credit_amount_apr        32820 non-null float64
# debit_count_apr          32820 non-null float64
# credit_count_apr         32820 non-null float64
# max_credit_amount_apr    32820 non-null float64
# debit_amount_may         32820 non-null float64
# ...

# %%
train_file.describe()
# Out:
#                 age   region_code  cc_count_apr  cc_count_may  cc_count_jun  \
# count  32820.000000  32820.000000  32820.000000  32820.000000  32820.000000
# mean      35.951676    554.854327      8.492474      9.205027     11.702864
# std        8.529949    188.220317     10.659069      9.638781     11.728113
# min       22.000000    123.000000      0.000000      0.000000      0.000000
# 25%       31.000000    425.000000      2.000000      3.000000      4.000000
# 50%       34.000000    575.000000      6.000000      7.000000      9.000000
# 75%       39.000000    683.000000     12.000000     13.000000     16.000000
# max      224.000000    977.000000   1012.000000    601.000000    653.000000
#
#        dc_count_apr  dc_count_may  dc_count_jun        card_lim  \
# count  32820.000000  32820.000000  32820.000000    32820.000000
# mean       2.205271      2.956399      4.168190   121553.749657
# std        4.751877      5.956464      7.758457   123002.957414
# ...

# %%
corr=train_file.corr()
corr
# Out:
#                             age  region_code  cc_count_apr  cc_count_may  \
# age                    1.000000    -0.033487      0.015697      0.017935
# region_code           -0.033487     1.000000      0.022109      0.022989
# cc_count_apr           0.015697     0.022109      1.000000      0.602486
# cc_count_may           0.017935     0.022989      0.602486      1.000000
# cc_count_jun           0.040105     0.005212      0.530674      0.721185
# dc_count_apr          -0.165602     0.060308     -0.084612     -0.049212
# dc_count_may          -0.165662     0.047291     -0.064771     -0.080625
# dc_count_jun          -0.168893     0.028607     -0.061374     -0.057462
# card_lim               0.359089    -0.025952      0.158925      0.176453
# debit_amount_apr       0.076466     0.005472      0.076341      0.080428
# credit_amount_apr      0.073827    -0.001418      0.073712      0.074530
# debit_count_apr       -0.169132     0.091168     -0.017829     -0.000385
# ...

# %%
X=train_file.drop('cc_cons',axis=1)
y=train_file['cc_cons']
print(X.shape)
X.head()
# Out:
# (32820, 29)
#   account_type gender  age  region_code  cc_count_apr  cc_count_may  \
# 0            1      1   63          305           2.0           1.0
# 1            2      1   33          326          11.0          14.0
# 2            2      1   44          264           6.0           9.0
# 3            1      1   44          233           9.0           6.0
# 4            1      2   35          324           2.0           7.0
#
#    cc_count_jun  dc_count_apr  dc_count_may  dc_count_jun       ...         \
# 0           3.0           0.0           0.0           0.0       ...
# 1          11.0           1.0           0.0           6.0       ...
# 2           6.0           3.0           2.0          14.0       ...
# 3           6.0           0.0           0.0           0.0       ...
# 4           9.0           0.0           0.0           0.0       ...
#
#    debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0              2.0                45000.0          20215.85
# ...

# %% [markdown]
# ###  Feature_selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=17)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=17, score_func=<function chi2 at 0x0000027E31024378>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
chi_feature
# Out:
# 18 selected features
# ['account_type',
#  'gender',
#  'region_code',
#  'dc_count_apr',
#  'dc_count_may',
#  'dc_count_jun',
#  'card_lim',
#  'debit_amount_apr',
#  'credit_amount_apr',
#  'debit_count_apr',
#  'credit_count_may',
#  'debit_count_may',
#  'max_credit_amount_may',
#  'debit_amount_jun',
#  'debit_count_jun',
#  'emi_active',
#  'debit_cons_avg',
#  'credit_cons_avg']

# %%
X=train_file[chi_feature]
y=train_file['cc_cons']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X.shape
# Out:
# (32820, 18)

# %%
test_file=test_file[chi_feature]
test_file.head(5)
# Out:
#   account_type gender  region_code  dc_count_apr  dc_count_may  dc_count_jun  \
# 0            1      1          447           1.0           0.0           0.0
# 1            2      1          233           0.0           0.0           0.0
# 2            2      1          823           8.0           3.0           3.0
# 3            2      1          878           0.0           0.0           0.0
# 4            2      1          404           0.0           0.0           0.0
#
#    card_lim  debit_amount_apr  credit_amount_apr  debit_count_apr  \
# 0   75000.0          10806.93            25279.0              7.0
# 1  116000.0              0.00                0.0              0.0
# 2   40000.0          83205.22           105813.0             33.0
# 3   86000.0          45342.25            59640.0              4.0
# 4  250000.0          25493.95            25154.0              4.0
#
#    credit_count_may  debit_count_may  max_credit_amount_may  debit_amount_jun  \
# ...

# %% [markdown]
# ###  Prediction Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
X_train.shape
# Out:
# (19692, 18)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19692, 18)
# (13128, 18)
# (19692,)
# (13128,)

# %%
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_squared_error
from sklearn import ensemble

# %%
# Fit regression model
params = {'n_estimators': 120, 'max_depth':10, 'min_samples_split': 2,'learning_rate': 0.05, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(learning_rate=0.05, min_samples_split=120,min_samples_leaf=50,max_depth=8,
                                         n_estimators=120,subsample=0.8,random_state=10)
clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)
msle = mean_squared_log_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % msle)
# Out:
# MSE: 127377305.0229
# MSE: 1.7920

# %%
select_row = test_file.loc[test_file1.id ==31659]
select_row
# Out:
#   account_type gender  region_code  dc_count_apr  dc_count_may  dc_count_jun  \
# 5            2      1          523           0.0           0.0           0.0
#
#    card_lim  debit_amount_apr  credit_amount_apr  debit_count_apr  \
# 5  132000.0          64807.75            64512.8              8.0
#
#    credit_count_may  debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 5               2.0              3.0                67838.5          108002.0
#
#    debit_count_jun  emi_active  debit_cons_avg  credit_cons_avg
# 5              5.0     1941.89             0.0          8707.63

# %%
clf.predict(select_row)
# Out:
# array([6003.12195435])

# %%
prediction=[]
prediction=clf.predict(test_file)
prediction=pd.DataFrame(prediction,columns=['cc_cons'])
prediction.head(5)
# Out:
#         cc_cons
# 0   4555.766916
# 1  10809.152749
# 2   3204.417448
# 3   7076.451747
# 4   7557.421692

# %%
predictions=pd.concat([test_file1['id'],prediction],axis=1)
predictions.head(5)
# Out:
#       id       cc_cons
# 0   6975   4555.766916
# 1  43223  10809.152749
# 2  45502   3204.417448
# 3  12368   7076.451747
# 4  40415   7557.421692

# %%
predictions.to_csv('submission_data.csv', encoding='utf-8')
